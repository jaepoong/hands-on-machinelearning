# %%
from sklearn.datasets import load_iris
import numpy as np
import pandas as pd

# %%
iris=load_iris()

# %%
x=iris.data
y=iris.target

# %%
x_len=int(len(x)*0.9)
y_len=int(len(y)*0.9)

# %%
x_train=x[:x_len]
x_test=x[x_len:]
y_train=y[:y_len]
y_test=y[y_len:]
