# %%
from sklearn.datasets import fetch_openml
import matplotlib.pyplot as plt
import matplotlib as mpl
import numpy as np
from sklearn.model_selection import train_test_split
mnist=fetch_openml('mnist_784',version=1)
x,y=mnist["data"][:1000],mnist["target"][:1000]
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

# %%
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.ensemble import VotingClassifier

# %%
svm_clf=SVC()
rnd_clf=RandomForestClassifier(n_estimators=100,max_depth=4)
et_clf=ExtraTreesClassifier(n_estimators=100,max_depth=4)
ab_clf=AdaBoostClassifier()
gd_clf=GradientBoostingClassifier()

# %%
vot_clf=VotingClassifier(
    estimators=[('svm',svm_clf),('rnd',rnd_clf),('et',et_clf),('ab',ab_clf),('gd',gd_clf)],
    voting="soft"
)
vot_clf.fit(x_train,y_train)
# Out:
# VotingClassifier(estimators=[('svm',
#                               SVC(C=1.0, break_ties=False, cache_size=200,
#                                   class_weight=None, coef0=0.0,
#                                   decision_function_shape='ovr', degree=3,
#                                   gamma='scale', kernel='rbf', max_iter=-1,
#                                   probability=False, random_state=None,
#                                   shrinking=True, tol=0.001, verbose=False)),
#                              ('rnd',
#                               RandomForestClassifier(bootstrap=True,
#                                                      ccp_alpha=0.0,
#                                                      class_weight=None,
#                                                      criterion='g...
#                                                          max_leaf_nodes=None,
#                                                          min_impurity_decrease=0.0,
# ...

# %%
pred=vot_clf.predict(x_test)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-32-e14e584b9c3c> in <module>()
# ----> 1 pred=vot_clf.predict(x_test)
#
# /usr/local/lib/python3.7/dist-packages/sklearn/ensemble/_voting.py in predict(self, X)
#     237         check_is_fitted(self)
#     238         if self.voting == 'soft':
# --> 239             maj = np.argmax(self.predict_proba(X), axis=1)
#     240
#     241         else:  # 'hard' voting
#
# /usr/local/lib/python3.7/dist-packages/sklearn/ensemble/_voting.py in _predict_proba(self, X)
#     257         """Predict class probabilities for X in 'soft' voting."""
#     258         check_is_fitted(self)
# --> 259         avg = np.average(self._collect_probas(X), axis=0,
#     260                          weights=self._weights_not_none)
#     261         return avg
#
# ...

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test,pred)
# Out:
# 0.85
